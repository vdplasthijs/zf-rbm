# %%
import os, sys
import numpy as np
import pandas as pd
# %run setup_notebook.ipynb
# Out:
# /home/thijs/.conda/envs/py37/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /home/thijs/repos/dnp-code/PGM3_correct/source/numba_utilities.py:1109: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 2d, F), array(float32, 2d, A))
#   dmean_v_dw = np.dot(s1.T, V)
# /home/thijs/repos/dnp-code/PGM3_correct/source/numba_utilities.py:1110: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 2d, F), array(float32, 2d, A))
#   dvar_e_dw = np.dot(s2.T, V)
# /home/thijs/repos/dnp-code/PGM3_correct/source/numba_utilities.py:1111: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 2d, F), array(float32, 2d, A))
#   tmp3 = np.dot(s3.T, V)
# /home/thijs/repos/dnp-code/PGM3_correct/source/numba_utilities.py:946: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float32, 1d, A), array(float32, 2d, A))
#   mean_V = np.dot(weights, V) / sum_weights
# /home/thijs/repos/dnp-code/rbm_pipeline_functions.py
# /home/thijs/.conda/envs/py37/lib/python3.7/site-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# baseline with shape (5553, 54334) is not recognized, so it cannot be loaded.
# drifts with shape (5553, 2) is not recognized, so it cannot be loaded.
# inferredspikes with shape (5553, 54334) is not recognized, so it cannot be loaded.
# ljpcoordinates with shape (3, 54334) is not recognized, so it cannot be loaded.
# segmentation with shape (30, 598, 1280) is not recognized, so it cannot be loaded.
# temporalmean with shape (30, 598, 1280) is not recognized, so it cannot be loaded.
# rawsignal with shape (5553, 54334) is not recognized, so it cannot be loaded.
# trace with shape (5553, 1) is not recognized, so it cannot be loaded.
# metadata with shape (1, 1) is not recognized, so it cannot be loaded.
# Recording from /media/thijs/hooghoudt/Zebrafish_data/spontaneous_data_guillaume/20180912_Run01_spontaneous_rbm2.h5
# len test inds 1665

# %%
sys.path.append('/home/thijs/repos/zf-rbm/figure_notebooks/')
import plotting_functions as pf
import analysis_functions as af
import swap_sign_RBM as ssrbm
pf.set_fontsize(font_size=12)
# %load_ext autoreload
# %autoreload 2

# %%
## Load annotation files
dir_path = '/home/thijs/repos/zf-rbm/figures/HU_info_2020-05-16-0844/not_sign_swapped'
annot_file = 'Volker_HU_manual_annotation_2020-11-27.txt'
annot_file_path = os.path.join(dir_path, annot_file)

new_dir = '/home/thijs/repos/zf-rbm/figures/HU_info_2020-05-16-0844/'
new_annot_file ='Volker_HU_manual_annotation_2020-11-27_signswapped.txt'

with open(annot_file_path, 'r') as f:
    content = f.readlines()
    
new_content = []

# %%
## Load RBM
rbm_path = '/media/thijs/hooghoudt/new_sweep_april20/RBM_sweep_reruns/RBM3_20180912-Run01-spontaneous-rbm2_wb_test-segs-267-nseg10_M200_l1-2e-02_duration208093s_timestamp2020-05-16-0844.data'
RBM_dict = {'old': pickle.load(open(rbm_path, 'rb'))}
RBM_dict['signswapped'] = ssrbm.swap_sign_RBM(RBM=RBM_dict['old'], verbose=2)

## two mappings
hu_act_test, hu_act_test_remap, ol = {}, {}, {}
for key, RBM in RBM_dict.items():
    hu_act_test[key] = np.transpose(RBM.mean_hiddens(test_data['wb'].T))
    ol[key] = af.opt_leaf(hu_act_test[key])
    hu_act_test_remap[key] = hu_act_test[key][ol[key], :]
# Out:
# 45/200 HU weights are flipped
# Flipped HUs are: (array([  1,  11,  12,  19,  30,  36,  37,  38,  41,  43,  52,  55,  67,
#         68,  70,  72,  88,  94,  95,  99, 100, 107, 111, 117, 118, 120,
#        124, 128, 133, 136, 138, 140, 151, 152, 167, 170, 171, 172, 175,
#        177, 181, 186, 188, 191, 198]),)
# /home/thijs/repos/dnp-code/PGM3_correct/source/layer.py:1152: RuntimeWarning: overflow encountered in true_divide
#   ) / (etg_plus / np.sqrt(self._gamma_plus)))

# %%
## align mappings:
nhu = 200
old_mapping = np.zeros((nhu, 2))
i_hu = 0
for new_index, old_index in enumerate(ol['old']):
    old_mapping[i_hu, 0] = old_index
    old_mapping[i_hu, 1] = new_index
    i_hu += 1
tmp_inds_sorted = np.argsort(old_mapping[:, 0])
old_mapping_sorted = old_mapping[tmp_inds_sorted, :]

signswapped_mapping = np.zeros((nhu, 2))
i_hu = 0
for new_index, old_index in enumerate(ol['signswapped']):
    signswapped_mapping[i_hu, 0] = old_index
    signswapped_mapping[i_hu, 1] = new_index
    i_hu += 1
tmp_inds_sorted = np.argsort(signswapped_mapping[:, 0])
signswapped_mapping_sorted = signswapped_mapping[tmp_inds_sorted, :]
    
translation_old_ol_to_new_ol = {}
for i_nhu in range(nhu):
    translation_old_ol_to_new_ol[int(old_mapping_sorted[i_nhu, 1])] = int(signswapped_mapping_sorted[i_nhu, 1])
    
assert translation_old_ol_to_new_ol[86] == signswapped_mapping_sorted[ol['old'][86], 1]  # check for random hU

# %%
translation_old_ol_to_new_ol
# Out:
# {132: 141,
#  6: 180,
#  175: 58,
#  103: 108,
#  65: 101,
#  129: 139,
#  87: 16,
#  88: 17,
#  98: 30,
#  159: 86,
#  99: 29,
#  35: 33,
#  11: 168,
#  57: 36,
#  123: 125,
#  74: 69,
#  152: 84,
#  136: 160,
#  69: 107,
#  4: 75,
#  125: 113,
#  140: 144,
#  124: 124,
#  178: 56,
#  163: 65,
#  41: 114,
#  66: 122,
#  196: 189,
#  135: 132,
#  81: 3,
#  38: 10,
#  59: 94,
#  162: 170,
#  119: 119,
#  1: 1,
#  64: 100,
#  18: 171,
#  14: 149,
#  9: 53,
#  90: 14,
#  185: 196,
#  5: 52,
#  148: 167,
#  10: 183,
#  195: 188,
#  128: 115,
#  199: 182,
#  61: 92,
#  105: 102,
#  126: 121,
#  80: 11,
#  151: 83,
#  107: 123,
#  166: 71,
#  79: 12,
#  32: 145,
#  112: 156,
#  157: 78,
#  104: 103,
#  62: 91,
#  156: 87,
#  72: 73,
#  158: 79,
#  43: 44,
#  97: 32,
#  145: 155,
#  141: 151,
#  110: 105,
#  40: 4,
#  127: 120,
#  22: 162,
#  187: 194,
#  37: 23,
#  45: 42,
#  155: 88,
#  182: 187,
#  190: 177,
#  44: 43,
#  146: 165,
#  118: 118,
#  89: 18,
#  67: 98,
#  144: 154,
#  42: 45,
#  153: 90,
#  46: 41,
#  116: 116,
#  48: 46,
#  33: 130,
#  138: 148,
#  53: 51,
#  63: 99,
#  172: 97,
#  75: 68,
#  13: 96,
#  12: 95,
#  198: 181,
#  121: 127,
#  51: 49,
#  28: 134,
#  30: 137,
#  154: 89,
#  131: 135,
#  47: 40,
#  115: 161,
#  174: 57,
#  197: 190,
#  8: 199,
#  133: 142,
#  84: 6,
#  50: 48,
#  109: 104,
#  120: 128,
#  93: 22,
#  56: 39,
#  77: 74,
#  194: 192,
#  3: 72,
#  111: 110,
#  83: 7,
#  34: 25,
#  170: 63,
#  113: 158,
#  189: 175,
#  23: 159,
#  54: 37,
#  70: 111,
#  176: 54,
#  15: 173,
#  86: 15,
#  171: 62,
#  68: 106,
#  192: 179,
#  19: 85,
#  181: 186,
#  91: 13,
#  31: 140,
#  52: 50,
#  17: 169,
#  58: 164,
#  29: 136,
#  85: 5,
#  169: 64,
#  92: 24,
#  96: 31,
#  101: 27,
#  177: 55,
#  186: 195,
#  168: 60,
#  73: 70,
#  179: 184,
#  20: 80,
#  21: 163,
#  173: 59,
#  143: 153,
#  191: 178,
#  106: 2,
#  193: 191,
#  184: 197,
#  114: 157,
#  147: 166,
#  130: 138,
#  134: 131,
#  122: 126,
#  95: 20,
#  55: 38,
#  117: 117,
#  36: 19,
#  139: 146,
#  100: 26,
#  160: 35,
#  7: 193,
#  2: 66,
#  71: 112,
#  142: 152,
#  39: 9,
#  0: 0,
#  16: 176,
#  150: 82,
#  180: 185,
#  165: 76,
#  161: 34,
#  76: 67,
#  108: 109,
#  49: 47,
#  164: 77,
#  25: 143,
#  94: 21,
#  27: 133,
#  149: 81,
#  60: 93,
#  24: 147,
#  137: 150,
#  188: 174,
#  167: 61,
#  82: 8,
#  78: 172,
#  102: 28,
#  26: 129,
#  183: 198}

# %%
indiv_units = True
new_content = []
new_lines_dict = {}
new_groups_dict = {}
for i_line, line in enumerate(content):
    # line = line.rstrip()  #\n
    if i_line == 0:
        new_content.append(line) # title 
    elif indiv_units:  # list of individual units
        split_line = line.split('=>')
        hu_index = split_line[0].lstrip('!').strip(' ')
        attention = split_line[0].rstrip(' ').rstrip(hu_index)
        new_hu_index = translation_old_ol_to_new_ol[int(hu_index)]
        new_line = attention + ' ' + str(new_hu_index) + ' ' +  ''.join(['=>' + x for x in split_line[1:]])  # replace with new index
        new_line = new_line.lstrip(' ')
        new_lines_dict[new_hu_index] = new_line  # save in dict to later to alphabetically
#         print(line, new_line)
        if int(hu_index) == 199:  # last one (hard coded)
            indiv_units = False
    else: # groupings at bottom of file
        line_split = line.split(':')
        if len(line_split) == 1:
            new_groups_dict[i_line] = line
            continue  # nothing here 
        
        else:
            assert len(line_split) == 2
            info_group = line_split[0]
            old_hu_list = line_split[1].split(', ')  # make sure all HUs are separated by comma space
            new_hu_list = old_hu_list.copy()
            tmp_arr_new_hu = np.zeros(len(new_hu_list))  # used for new alphabetical sorting 
            for i_hu, old_hu in enumerate(old_hu_list):
                old_hu_index = int(''.join(i for i in old_hu if i.isdigit()))  # only get digits
                new_hu_list[i_hu] = new_hu_list[i_hu].replace(str(old_hu_index), 
                                                              str(translation_old_ol_to_new_ol[old_hu_index]))  # replace, so !! are kept intact
                tmp_arr_new_hu[i_hu] = translation_old_ol_to_new_ol[old_hu_index]
            sorted_new_hu_inds = np.argsort(tmp_arr_new_hu)  # determine new sorting
            sorted_new_hu_list = [new_hu_list[x].rstrip('\n') for x in sorted_new_hu_inds]  # like this, so !! are maintained
            new_line = info_group + ': ' + ', '.join(sorted_new_hu_list) + '\n'  # remake 
            new_groups_dict[i_line] = new_line
#             print(info_group, old_hu_list, new_hu_list, new_line)

# for i_line, new_line in new_lines_dict.items():

for i_line in range(200):  # add alphabetically 
    if i_line in new_lines_dict.keys():
        new_content.append(new_lines_dict[i_line])
for i_line, new_line in new_groups_dict.items():
    new_content.append(new_line)

print(new_content)
# Out:
# ['HU:\n', '5 => small but very active\n', '10 => tectum neuropil\n', '13 => Tectrum stratum periventriculars\n', '14 => Tectrum stratum periventriculars\n', '15 => Tectrum stratum periventriculars\n', '16 => Tectrum stratum periventriculars\n', '17 => Tectrum stratum periventriculars\n', '18 => Tectrum stratum periventriculars\n', '20 => Tectrum stratum periventriculars \n', '21 => Tectrum stratum periventriculars\n', '22 => Tectrum stratum periventriculars\n', '23 => tectum stratum periventriculare => medial\n', '24 => Tectrum stratum periventriculars\n', '25 => tectum stratum periventriculare => medial\n', '26 => Tectrum stratum periventriculars \n', '27 => Tectrum stratum periventriculars \n', '28 => Tectrum stratum periventriculars\n', '29 => Tectrum stratum periventriculars \n', '30 => Tectrum stratum periventriculars \n', '31 => Tectrum stratum periventriculars \n', '32 => Tectrum stratum periventriculars \n', '!!!  35 => left right symmetry between inhibitory and exitatory cluster\n', '38 => statoacoustic ganglion\n', '42 => nIII -> saccarde circuit ?\n', '43 => nIII -> saccarde circuit  ?\n', '45 => oscillator ?\n', '!  47 => Gad1b stripe 3 ; Glyt stripe 3; Vglut2 stripe 3\n', '!  48 => Gad1b stripe 2 ; Vglut2 stripe 2\n', '49 => nV Trigeminal Motorneurons ; VII facial motor and octavolateralis efferent neurons; olig2 stripe\n', '53 => nIII\n', '54 => == 175\n', '!!  55 => medial vestibular nucleus + oculomotor neurons? + preteritum ?\n', '!  58 => two clusters around ears \n', '!!  59 => nV + Isl1 motor neurons + Spinal cord + nice clusters at midbrain-hindbrain boundary  => related to behaviour?\n', '60 => many neurons but symmetric in hindbrain\n', '!  61 => blue midbrain + red hindbrain\n', '62 => vagus motor neurons + vagus ganglion == 169\n', '!  63 => brain wide cluster from Diencephalon to midbrain to hindbrain\n', '!  64 => vagus motor neurons + vagus ganglion\n', '!  67 => similar to 75 but less neurons and similar activity\n', '!  68 => Spinal cord ; RS neurons ; two symmetric nice clusters ; purkinje cells ? \n', '!  69 => Spinal cord and well defined small and symmetric hindbrain regions\n', '75 => oscillator ?\n', '!  76 => big lateral cluster perhaps related to strong tail flip ???\n', '!!  78 => oscillator\n', '!!  79 => statoacoustic ganglion; tangential vestibular nucleus; =>  slow decay activity  == 156\n', '!  80 => VII facial motor  and ovtovolateralis effent neurons => Interesting !!!\n', '!  81 => medial hindbrain stripes\n', '!  82 => medial hindbrain stripes (especially looks interesting)\n', '!  83 => medial hindbrain stripes\n', '84 => oscillator\n', '85 => small clearly defined hindbrain cluster MidD2 => what is this?\n', '!!  86 => small number of neurons => interesting bimodal activity\n', '!!  87 => statoacoustic ganglion; tangential vestibular nucleus; RS vestibular population => slow decay activity \n', '89 => saccarde circuit\n', '90 => nMLF and hindbrain cluster\n', '!  91 => Corpus Cerebelli ; Cerebellar Vglut2  => granular cells ?\n', '95 => neuromodulation ? Raphe + Gad1b + volut2\n', '96 => vagal motor neurons + vagal ganglia !\n', '!!  97 => nice symmetric cerebellar cluster\n', '103 => broadly distributed\n', '!  108 => small active double cluster => not sure what this is\n', '!  109 => symmetric cerebellum; nIV ; hypothalamus and others\n', '113 => diffuse but symmetric\n', '116 => diffuse\n', '!  117 => diffuse But => symmetric blue and red organisation\n', '118 => diffuse\n', '119 => clear cluster in rhombencephalon\n', '!  120 => as 126 but mirror symmetric to the mid plane\n', '!  121 => asymmetric cluster\n', '124 => locus coreueleus (noradrenergic nucleus) + torus semicirucalis + cerebellum\n', '!  127 => as 120 but more diffuse\n', '!!  128 => lobus caudalis cerebelli + contralateral cluster in rhombomere 2\n', '129 =>  torus semicircularis\n', '130 => tectum stratum periventriculare => medial   <=> 32\n', '131 => Tectum stratum periventriculars\n', '132 => Tectum stratu ...

# %%
## Write to new file
# with open(os.path.join(new_dir, new_annot_file), 'w') as new_f:
#     for line in new_content:
#         new_f.write(line)

# %%
## do the few references to other HUs in the individual part by hand
translation_old_ol_to_new_ol[113]
# Out:
# 158
